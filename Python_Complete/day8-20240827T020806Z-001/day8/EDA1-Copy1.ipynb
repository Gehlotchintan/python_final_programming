# %% [markdown]
# # Create DataFrame

# %%
data = {
    'id': [1,2,3,4],
    'age': [23, 24, 34, 25],
    'height': [175, 166, 167, 188]
}

# %% [markdown]
# # HEAD & TAIL

# %% [markdown]
# # Check Shape and Dimension

# %% [markdown]
# # Columns and Index

# %% [markdown]
# #  Drop Columns and Rows

# %%
# Drop rows

# %%
# drop columns

# %% [markdown]
# # Add Columns and Rows

# %%
# add columns

# %%
# add rows

# %% [markdown]
# # Chnage Index

# %% [markdown]
# # Rename Columns and Indexes

# %%
# rename columns

# %%
# rename indexes

# %% [markdown]
# # Filtering loc[] and iloc[] and boolean masking

# %%
df2 = pd.read_csv('weatherbyDay.csv')
df2

# %%
# boolean masking

# %%
df3 = pd.read_csv('weatherbyCity.csv')
df3

# %% [markdown]
# # Pivot, Pivot_table and Melt

# %%
df6 = pd.read_csv('weatherbyCity.csv')
df6

# %%
# pivot

# %%
# pivot table

# %%
# melt

# %% [markdown]
# # Changing Datatype of a Column

# %% [markdown]
# # Sorting

# %% [markdown]
# # Group By

# %% [markdown]
# # Joins

# %%
humidity = pd.read_csv('humidity.csv')
temp = pd.read_csv('temperature.csv')

# %% [markdown]
# # Dropping Duplicates

# %% [markdown]
# # apply

# %%
# apply

# %%
# transform

# %% [markdown]
# # Time Frame check
