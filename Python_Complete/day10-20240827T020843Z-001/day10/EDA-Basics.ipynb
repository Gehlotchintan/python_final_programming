# %% [markdown]
# # Data Analysis
#  - Data analysis is a broad term that refers to the process of inspecting, cleaning, transforming, and modeling data with the goal of extracting useful insights and information from it. This can involve a wide range of techniques and tools, including statistical analysis, machine learning, and data visualization.
#
# # Exploratory Data Analysis
# - Exploratory data analysis (EDA) is a specific type of data analysis that is focused on gaining an initial understanding of the data and identifying any patterns, trends, or relationships that may be present. This is typically done before more advanced techniques are applied and can involve various methods such as data visualization, summary statistics, and hypothesis testing.

# %% [markdown]
# # Steps Of EDA

# %% [markdown]
# ## importing required Libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('Sales_data_sample.csv')

# %%
df
# Out:
#       ORDER_NUMBER  QUANTITY_ORDERED  PRICE_EACH  ORDER_LINE_NUMBER    SALES  \
# 0            10107                30       95.70                  2  2871.00
# 1            10121                34       81.35                  5  2765.90
# 2            10134                41       94.74                  2  3884.34
# 3            10145                45       83.26                  6  3746.70
# 4            10159                49      100.00                 14  5205.27
# ...            ...               ...         ...                ...      ...
# 2818         10350                20      100.00                 15  2244.40
# 2819         10373                29      100.00                  1  3978.51
# 2820         10386                43      100.00                  4  5417.57
# 2821         10397                34       62.24                  1  2116.16
# 2822         10414                47       65.52                  9  3079.44
#
# ...

# %% [markdown]
# ## Validate few lines of dataset

# %%
df.head()
# Out:
#    ORDER_NUMBER  QUANTITY_ORDERED  PRICE_EACH  ORDER_LINE_NUMBER    SALES  \
# 0         10107                30       95.70                  2  2871.00
# 1         10121                34       81.35                  5  2765.90
# 2         10134                41       94.74                  2  3884.34
# 3         10145                45       83.26                  6  3746.70
# 4         10159                49      100.00                 14  5205.27
#
#         ORDER_DATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1  05-07-2003 0:00  Shipped       2         5     2003  ...
# 2  07-01-2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10-10-2003 0:00  Shipped       4        10     2003  ...
#
#               CUSTOMER_NAME             PHONE           CITY STATE POSTALCODE  \
# ...

# %%
df.tail()
# Out:
#       ORDER_NUMBER  QUANTITY_ORDERED  PRICE_EACH  ORDER_LINE_NUMBER    SALES  \
# 2818         10350                20      100.00                 15  2244.40
# 2819         10373                29      100.00                  1  3978.51
# 2820         10386                43      100.00                  4  5417.57
# 2821         10397                34       62.24                  1  2116.16
# 2822         10414                47       65.52                  9  3079.44
#
#            ORDER_DATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12-02-2004 0:00   Shipped       4        12     2004  ...
# 2819   1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820  03-01-2005 0:00  Resolved       1         3     2005  ...
# 2821   3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822  05-06-2005 0:00   On Hold       2         5     2005  ...
#
#                 CUSTOMER_NAME           PHONE      CITY STATE POSTALCODE  \
# ...

# %% [markdown]
# ## Check the Shape of Data
#  - Rows
#  - Columns

# %%
df.columns
# Out:
# Index(['ORDER_NUMBER', 'QUANTITY_ORDERED', 'PRICE_EACH', 'ORDER_LINE_NUMBER',
#        'SALES', 'ORDER_DATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCT_LINE', 'MSRP', 'PRODUCT_CODE', 'CUSTOMER_NAME', 'PHONE',
#        'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY',
#        'CONTACT_LAST_NAME', 'CONTACT_FIRST_NAME', 'DEAL_SIZE'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2823, step=1)

# %% [markdown]
# ## Check dataset Structure
# - verify columns format
# - check for non-null values
# - memory usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ORDER_NUMBER        2823 non-null   int64
#  1   QUANTITY_ORDERED    2823 non-null   int64
#  2   PRICE_EACH          2823 non-null   float64
#  3   ORDER_LINE_NUMBER   2823 non-null   int64
#  4   SALES               2819 non-null   float64
#  5   ORDER_DATE          2823 non-null   object
#  6   STATUS              2823 non-null   object
#  7   QTR_ID              2823 non-null   int64
#  8   MONTH_ID            2823 non-null   int64
#  9   YEAR_ID             2823 non-null   int64
#  10  PRODUCT_LINE        2823 non-null   object
#  11  MSRP                2823 non-null   int64
#  12  PRODUCT_CODE        2823 non-null   object
#  13  CUSTOMER_NAME       2823 non-null   object
#  14  PHONE               2823 non-null   object
# ...

# %% [markdown]
# ## Check Descriptive Stats
# - mean
# - Standard Deviation
# - min, max
# - Quartiles 25%, 50%, 75%

# %%
df.describe()
# Out:
#        ORDER_NUMBER  QUANTITY_ORDERED   PRICE_EACH  ORDER_LINE_NUMBER  \
# count   2823.000000       2823.000000  2823.000000        2823.000000
# mean   10258.725115         35.092809    83.658544           6.466171
# std       92.085478          9.741443    20.174277           4.225841
# min    10100.000000          6.000000    26.880000           1.000000
# 25%    10180.000000         27.000000    68.860000           3.000000
# 50%    10262.000000         35.000000    95.700000           6.000000
# 75%    10333.500000         43.000000   100.000000           9.000000
# max    10425.000000         97.000000   100.000000          18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2819.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3551.433111     2.717676     7.092455  2003.81509   100.715551
# std     1840.672309     1.203878     3.656633     0.69967    40.187912
# ...

# %%
df.describe().T
# Out:
#                     count          mean          std       min        25%  \
# ORDER_NUMBER       2823.0  10258.725115    92.085478  10100.00  10180.000
# QUANTITY_ORDERED   2823.0     35.092809     9.741443      6.00     27.000
# PRICE_EACH         2823.0     83.658544    20.174277     26.88     68.860
# ORDER_LINE_NUMBER  2823.0      6.466171     4.225841      1.00      3.000
# SALES              2819.0   3551.433111  1840.672309    482.13   2202.795
# QTR_ID             2823.0      2.717676     1.203878      1.00      2.000
# MONTH_ID           2823.0      7.092455     3.656633      1.00      4.000
# YEAR_ID            2823.0   2003.815090     0.699670   2003.00   2003.000
# MSRP               2823.0    100.715551    40.187912     33.00     68.000
#
#                         50%        75%      max
# ORDER_NUMBER       10262.00  10333.500  10425.0
# QUANTITY_ORDERED      35.00     43.000     97.0
# PRICE_EACH            95.70    100.000    100.0
# ...

# %% [markdown]
# ## Treat missing Values
# - Check missing Values
# - Ways to treat
#     - drop Columns/rows
#     - filling with Constant, Mean, Mode, as Previous/next row
#     - Predicting

# %%
# check missing values
df.isnull()
# Out:
#       ORDER_NUMBER  QUANTITY_ORDERED  PRICE_EACH  ORDER_LINE_NUMBER  SALES  \
# 0            False             False       False              False  False
# 1            False             False       False              False  False
# 2            False             False       False              False  False
# 3            False             False       False              False  False
# 4            False             False       False              False  False
# ...            ...               ...         ...                ...    ...
# 2818         False             False       False              False  False
# 2819         False             False       False              False  False
# 2820         False             False       False              False  False
# 2821         False             False       False              False  False
# 2822         False             False       False              False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# ORDER_NUMBER             0
# QUANTITY_ORDERED         0
# PRICE_EACH               0
# ORDER_LINE_NUMBER        0
# SALES                    4
# ORDER_DATE               0
# STATUS                   0
# QTR_ID                   0
# MONTH_ID                 0
# YEAR_ID                  0
# PRODUCT_LINE             0
# MSRP                     0
# PRODUCT_CODE             0
# CUSTOMER_NAME            0
# PHONE                    0
# CITY                     0
# STATE                 1486
# POSTALCODE              76
# COUNTRY                  0
# TERRITORY             1074
# CONTACT_LAST_NAME        0
# CONTACT_FIRST_NAME       0
# DEAL_SIZE                0
# dtype: int64

# %%
# way - remove rows

# %%
df.SALES.dropna()
# Out:
# 0       2871.00
# 1       2765.90
# 2       3884.34
# 3       3746.70
# 4       5205.27
#          ...
# 2818    2244.40
# 2819    3978.51
# 2820    5417.57
# 2821    2116.16
# 2822    3079.44
# Name: SALES, Length: 2819, dtype: float64

# %%
# way - drop columns

# %%
df.dropna(axis=1)
# Out:
#       ORDER_NUMBER  QUANTITY_ORDERED  PRICE_EACH  ORDER_LINE_NUMBER  \
# 0            10107                30       95.70                  2
# 1            10121                34       81.35                  5
# 2            10134                41       94.74                  2
# 3            10145                45       83.26                  6
# 4            10159                49      100.00                 14
# ...            ...               ...         ...                ...
# 2818         10350                20      100.00                 15
# 2819         10373                29      100.00                  1
# 2820         10386                43      100.00                  4
# 2821         10397                34       62.24                  1
# 2822         10414                47       65.52                  9
#
#            ORDER_DATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID PRODUCT_LINE  MSRP  \
# ...

# %%
df1 = df.copy()
df1[~df1.SALES.isnull()]
# Out:
#       ORDER_NUMBER  QUANTITY_ORDERED  PRICE_EACH  ORDER_LINE_NUMBER    SALES  \
# 0            10107                30       95.70                  2  2871.00
# 1            10121                34       81.35                  5  2765.90
# 2            10134                41       94.74                  2  3884.34
# 3            10145                45       83.26                  6  3746.70
# 4            10159                49      100.00                 14  5205.27
# ...            ...               ...         ...                ...      ...
# 2818         10350                20      100.00                 15  2244.40
# 2819         10373                29      100.00                  1  3978.51
# 2820         10386                43      100.00                  4  5417.57
# 2821         10397                34       62.24                  1  2116.16
# 2822         10414                47       65.52                  9  3079.44
#
# ...

# %%
df1.drop(columns=['STATE'])
# Out:
#       ORDER_NUMBER  QUANTITY_ORDERED  PRICE_EACH  ORDER_LINE_NUMBER    SALES  \
# 0            10107                30       95.70                  2  2871.00
# 1            10121                34       81.35                  5  2765.90
# 2            10134                41       94.74                  2  3884.34
# 3            10145                45       83.26                  6  3746.70
# 4            10159                49      100.00                 14  5205.27
# ...            ...               ...         ...                ...      ...
# 2818         10350                20      100.00                 15  2244.40
# 2819         10373                29      100.00                  1  3978.51
# 2820         10386                43      100.00                  4  5417.57
# 2821         10397                34       62.24                  1  2116.16
# 2822         10414                47       65.52                  9  3079.44
#
# ...

# %%
# fillin with Constant
after_fill = df1.fillna(456)
after_fill.isnull().sum()
# Out:
# ORDER_NUMBER          0
# QUANTITY_ORDERED      0
# PRICE_EACH            0
# ORDER_LINE_NUMBER     0
# SALES                 0
# ORDER_DATE            0
# STATUS                0
# QTR_ID                0
# MONTH_ID              0
# YEAR_ID               0
# PRODUCT_LINE          0
# MSRP                  0
# PRODUCT_CODE          0
# CUSTOMER_NAME         0
# PHONE                 0
# CITY                  0
# STATE                 0
# POSTALCODE            0
# COUNTRY               0
# TERRITORY             0
# CONTACT_LAST_NAME     0
# CONTACT_FIRST_NAME    0
# DEAL_SIZE             0
# dtype: int64

# %%
# df1.loc[~df1.SALES.isnull(), 'SALES'] = 456

# %%
# fill with mean
after_fill = df1.fillna(df1.SALES.mean())
after_fill.isnull().sum()
# Out:
# ORDER_NUMBER          0
# QUANTITY_ORDERED      0
# PRICE_EACH            0
# ORDER_LINE_NUMBER     0
# SALES                 0
# ORDER_DATE            0
# STATUS                0
# QTR_ID                0
# MONTH_ID              0
# YEAR_ID               0
# PRODUCT_LINE          0
# MSRP                  0
# PRODUCT_CODE          0
# CUSTOMER_NAME         0
# PHONE                 0
# CITY                  0
# STATE                 0
# POSTALCODE            0
# COUNTRY               0
# TERRITORY             0
# CONTACT_LAST_NAME     0
# CONTACT_FIRST_NAME    0
# DEAL_SIZE             0
# dtype: int64

# %%
# fill with median
after_fill = df1.fillna(df1.SALES.median())
after_fill.isnull().sum()
# Out:
# ORDER_NUMBER          0
# QUANTITY_ORDERED      0
# PRICE_EACH            0
# ORDER_LINE_NUMBER     0
# SALES                 0
# ORDER_DATE            0
# STATUS                0
# QTR_ID                0
# MONTH_ID              0
# YEAR_ID               0
# PRODUCT_LINE          0
# MSRP                  0
# PRODUCT_CODE          0
# CUSTOMER_NAME         0
# PHONE                 0
# CITY                  0
# STATE                 0
# POSTALCODE            0
# COUNTRY               0
# TERRITORY             0
# CONTACT_LAST_NAME     0
# CONTACT_FIRST_NAME    0
# DEAL_SIZE             0
# dtype: int64

# %%
# filling from previous row
df1.SALES.ffill()
# Out:
# 0       2871.00
# 1       2765.90
# 2       3884.34
# 3       3746.70
# 4       5205.27
#          ...
# 2818    2244.40
# 2819    3978.51
# 2820    5417.57
# 2821    2116.16
# 2822    3079.44
# Name: SALES, Length: 2823, dtype: float64

# %%
# filling from next row
df1.SALES.bfill()
# Out:
# 0       2871.00
# 1       2765.90
# 2       3884.34
# 3       3746.70
# 4       5205.27
#          ...
# 2818    2244.40
# 2819    3978.51
# 2820    5417.57
# 2821    2116.16
# 2822    3079.44
# Name: SALES, Length: 2823, dtype: float64

# %% [markdown]
# ##  Treat Outliers
# - Detect Outliers
#     - Box Plot
#     - Violin Plot
#     - IQR
# - Ways to handle
#     - Droping outliers
#     - Imputation - **Median**
#     - Quantile based flooring and capping
#     - Transformations - Log transformation can help to reduce the effect of outliers

# %%
df.SALES
# Out:
# 0       2871.00
# 1       2765.90
# 2       3884.34
# 3       3746.70
# 4       5205.27
#          ...
# 2818    2244.40
# 2819    3978.51
# 2820    5417.57
# 2821    2116.16
# 2822    3079.44
# Name: SALES, Length: 2823, dtype: float64

# %%
# using boxplot
sns.boxplot(data=df, x='SALES')
# Out:
# <Axes: xlabel='SALES'>

# %%
# using violinplot
sns.violinplot(data=df, x='SALES')
# Out:
# <Axes: xlabel='SALES'>

# %%
# using violinplot
sns.violinplot(data=df, y='SALES')
plt.show()

# %%
# detect and extract outliers - way
Q1 = df.SALES.quantile(0.25)
Q3 = df.SALES.quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# 2300.2999999999993

# %%
upper_bound = Q3 + 1.5*IQR
lower_bound = Q1 - 1.5*IQR
lower_bound, upper_bound
# Out:
# (-1247.6549999999988, 7953.544999999998)

# %%
# extract
df.loc[df.SALES > upper_bound, 'SALES']
# Out:
# 30      10993.50
# 32       8014.82
# 35       9064.89
# 41       8014.82
# 43      10172.70
#           ...
# 2241     8844.12
# 2295     8209.44
# 2430     8977.05
# 2505    10066.60
# 2634     9558.80
# Name: SALES, Length: 83, dtype: float64

# %%
# Way - 1 Treating outliers by dropping
after_dro_out = df.loc[~(df.SALES > upper_bound)]
after_dro_out
# Out:
#       ORDER_NUMBER  QUANTITY_ORDERED  PRICE_EACH  ORDER_LINE_NUMBER    SALES  \
# 0            10107                30       95.70                  2  2871.00
# 1            10121                34       81.35                  5  2765.90
# 2            10134                41       94.74                  2  3884.34
# 3            10145                45       83.26                  6  3746.70
# 4            10159                49      100.00                 14  5205.27
# ...            ...               ...         ...                ...      ...
# 2818         10350                20      100.00                 15  2244.40
# 2819         10373                29      100.00                  1  3978.51
# 2820         10386                43      100.00                  4  5417.57
# 2821         10397                34       62.24                  1  2116.16
# 2822         10414                47       65.52                  9  3079.44
#
# ...

# %%
# using boxplot
sns.boxplot(data=after_dro_out, x='SALES')
# Out:
# <Axes: xlabel='SALES'>

# %%
# Way 2 - Quatile based flooring and capping
cap = df1.SALES.quantile(0.96)
df1.loc[(df1.SALES > upper_bound), 'SALES'] = cap

# %%
df1.loc[(df1.SALES > upper_bound), 'SALES']
# Out:
# Series([], Name: SALES, dtype: float64)

# %%
# using boxplot
sns.boxplot(data=df1, x='SALES')
# Out:
# <Axes: xlabel='SALES'>

# %%
# Way 3 - imputing using median
df1.loc[(df1.SALES > upper_bound), 'SALES'] = df1.SALES.median()

# %%
# Way - Log Transformation
sns.boxplot(data=df, x='SALES')
# Out:
# <Axes: xlabel='SALES'>

# %%
sales = np.log(df.SALES)
sales
# Out:
# 0       7.962416
# 1       7.925121
# 2       8.264708
# 3       8.228631
# 4       8.557427
#           ...
# 2818    7.716194
# 2819    8.288663
# 2820    8.597403
# 2821    7.657358
# 2822    8.032503
# Name: SALES, Length: 2823, dtype: float64

# %%
sns.boxplot(x=sales)
# Out:
# <Axes: xlabel='SALES'>

# %%
# Task
# drop ouliers from sales_log
#

# %% [markdown]
# ## Cheking for correlations

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df.corr()
#
# File C:\python\lib\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\python\lib\site-packages\pandas\core\frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# -> 1892 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1893 if result.dtype is not dtype:
#    1894     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
df.corr()[['SALES', 'MSRP', "PRICE_EACH"]]

# %%
# heatmap
sns.heatmap(df.corr()[['SALES', 'MSRP', "PRICE_EACH"]], annot=True)

# %% [markdown]
# ## Graph Visualization
# - **Scatter Plot**
#     - Scatter plots are a type of data visualization used to display the relationship between two continuous variables.
#     - They can be useful for identifying patterns or trends in data, and for detecting outliers or anomalies.
#     - Scatter plots can also be used to explore the correlation or causation between variables, and to identify potential relationships or associations that may exist.
# - **Bar Plot**
#     - A bar plot is a data visualization that represents data with rectangular bars.
#     - where the length of each bar corresponds to the magnitude of the value it represents.
# - **Histogram**
#     - A histogram is a type of data visualization that displays the distribution of a numerical variable.
#     - It divides the range of the variable into intervals called bins and shows the number of observations that fall into each bin as a bar.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ORDER_NUMBER        2823 non-null   int64
#  1   QUANTITY_ORDERED    2823 non-null   int64
#  2   PRICE_EACH          2823 non-null   float64
#  3   ORDER_LINE_NUMBER   2823 non-null   int64
#  4   SALES               2819 non-null   float64
#  5   ORDER_DATE          2823 non-null   object
#  6   STATUS              2823 non-null   object
#  7   QTR_ID              2823 non-null   int64
#  8   MONTH_ID            2823 non-null   int64
#  9   YEAR_ID             2823 non-null   int64
#  10  PRODUCT_LINE        2823 non-null   object
#  11  MSRP                2823 non-null   int64
#  12  PRODUCT_CODE        2823 non-null   object
#  13  CUSTOMER_NAME       2823 non-null   object
#  14  PHONE               2823 non-null   object
# ...

# %% [markdown]
# **Line Plot**

# %%
x = np.linspace(0, 1, 100)
y = x * np.sin(x)
plt.figure(figsize=(10, 5))
plt.plot(x, y, color='orange', linewidth=5)
plt.title("X vs Y")
plt.xlabel("X")
plt.ylabel("Y")
plt.xlim([0.2, 0.8])
plt.show()

# %% [markdown]
# **Scatter plot**

# %%
# way 1
plt.scatter(df.MSRP, df.SALES)
plt.show()

# %%
# way 2
sns.scatterplot(data=df, x='MSRP', y='SALES', palette='Set 2')
plt.show()
# Out:
# C:\Users\skhap\AppData\Local\Temp\ipykernel_1948\4057240246.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x='MSRP', y='SALES', palette='Set2')

# %%
# way 2
sns.scatterplot(data=df, x='MSRP', y='SALES', hue='STATUS', palette='Set2')
plt.show()

# %%
# way 3
df.plot.scatter(x='MSRP', y='SALES')
# Out:
# <Axes: xlabel='MSRP', ylabel='SALES'>

# %% [markdown]
# **Histogram**

# %%
# way 1
plt.hist(df.SALES, bins=15, color='lightgreen')
plt.show()

# %%
# way 1
plt.hist(df.SALES, bins=15, color='lightgreen', orientation='horizontal')
plt.show()

# %%
# way 2
sns.histplot(data=df, x='SALES', bins=15)
# Out:
# <Axes: xlabel='SALES', ylabel='Count'>

# %%
# way 2
sns.histplot(data=df, y='SALES', bins=15)
# Out:
# <Axes: xlabel='Count', ylabel='SALES'>

# %%
# way 2
sns.histplot(data=df, x='SALES', bins=15, kde=True)
# Out:
# <Axes: xlabel='SALES', ylabel='Count'>

# %%
df.plot.hist(y='SALES', bins=10, orientation='horizontal')
# Out:
# <Axes: xlabel='Frequency'>

# %% [markdown]
# **Bar Plot**

# %%
df.STATUS.value_counts().index
# Out:
# Index(['Shipped', 'Cancelled', 'Resolved', 'On Hold', 'In Process',
#        'Disputed'],
#       dtype='object', name='STATUS')

# %%
df.STATUS.value_counts().values
# Out:
# array([2617,   60,   47,   44,   41,   14], dtype=int64)

# %%
# way 1
plt.bar(df.STATUS.value_counts().index, df.STATUS.value_counts().values)
plt.show()

# %%
# way 1
plt.barh(df.STATUS.value_counts().index, df.STATUS.value_counts().values)
plt.show()

# %%
# way 2
sns.barplot(x=df.STATUS.value_counts().index, y=df.STATUS.value_counts().values)
# Out:
# <Axes: xlabel='STATUS'>

# %%
sns.countplot(data=df, x='STATUS', hue='STATUS')
# Out:
# <Axes: xlabel='STATUS', ylabel='count'>

# %% [markdown]
# **Pie**

# %%
plt.pie(df.STATUS.value_counts().values, labels=df.STATUS.value_counts().index, autopct='%.2f%%')
plt.show()

# %%
plt.pie(df.STATUS.value_counts().values, labels=df.STATUS.value_counts().index, autopct='%.2f%%')
plt.savefig('pie.png', dpi=200)
plt.show()

# %% [markdown]
# **3D Visualization**

# %%
axes = plt.axes(projection='3d')
axes.scatter3D(
    df.MSRP,
    df.PRICE_EACH,
    df.SALES
)
axes.set_xlabel('MSRP')
axes.set_ylabel('PRICE_EACH')
axes.set_zlabel('SALES')
# Out:
# Text(0.5, 0, 'SALES')

# %%
axes = plt.axes(projection='3d')
axes.plot3D(
    df.MSRP,
    df.PRICE_EACH,
    df.SALES
)
axes.set_xlabel('MSRP')
axes.set_ylabel('PRICE_EACH')
axes.set_zlabel('SALES')
# Out:
# Text(0.5, 0, 'SALES')
