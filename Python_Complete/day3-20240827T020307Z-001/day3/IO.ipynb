# %% [markdown]
# # Basic IO
# <img src="io.jpg">

# %%
subject = input("Subject: ")
subject
# Out:
# Subject: Machine Learning
# 'Machine Learning'

# %%
lucky_num = int(input())
lucky_num
# Out:
# 34
# 34

# %% [markdown]
# # map()
# <img src="map.jpg">

# %%
sales = int(input("Sales of Last 4 weeks: "))
sales
# Out:
# Sales of Last 4 weeks: [2000, 1500, 1700, 1800]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 sales = int(input("Sales of Last 4 weeks: "))
#       2 sales
#
# ValueError: invalid literal for int() with base 10: '[2000, 1500, 1700, 1800]'

# %%
input("Sales of Last 4 weeks: ").split(' ')
# Out:
# Sales of Last 4 weeks: 2000 1500 1700 1800
# ['2000', '1500', '1700', '1800']

# %%
2000 1500 1700 1800

# %%
sales = list(map(int, input("Sales of Last 4 weeks: ").split(' ')))
sales
# Out:
# Sales of Last 4 weeks: 300 400 500 600
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-c16610b9117e> in <cell line: 1>()
# ----> 1 sales = list(map(int, input("Sales of Last 4 weeks: ").split(' ')))
#       2 sales
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# # Evaluate Expression

# %%
m = 0.9
c = 2
x = 45
y = m*x + c
y
# Out:
# 42.5

# %%
eval("m*x + c")
# Out:
# 42.5

# %%
eval(input("Equation over m, x, c: "))
# Out:
# Equation over m, x, c: m*x + c
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0d88f8603ee8> in <cell line: 1>()
# ----> 1 eval(input("Equation over m, x, c: "))
#
# <string> in <module>
#
# NameError: name 'm' is not defined
